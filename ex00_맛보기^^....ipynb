# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Spotify-module-설치" data-toc-modified-id="Spotify-module-설치-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Spotify module 설치</a></span></li><li><span><a href="#API-접속하기-위한-인증-과정" data-toc-modified-id="API-접속하기-위한-인증-과정-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>API 접속하기 위한 인증 과정</a></span></li><li><span><a href="#가수-정보-가져오기" data-toc-modified-id="가수-정보-가져오기-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>가수 정보 가져오기</a></span><ul class="toc-item"><li><span><a href="#serarch()" data-toc-modified-id="serarch()-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>serarch()</a></span></li><li><span><a href="#가수-정보-확인하기" data-toc-modified-id="가수-정보-확인하기-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>가수 정보 확인하기</a></span></li><li><span><a href="#artist()" data-toc-modified-id="artist()-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>artist()</a></span></li><li><span><a href="#artist_album" data-toc-modified-id="artist_album-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>artist_album</a></span></li><li><span><a href="#album_tracks-(album_id,-limit)" data-toc-modified-id="album_tracks-(album_id,-limit)-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>album_tracks (album_id, limit)</a></span></li><li><span><a href="#Doja-Cat-상위-트랙-5개-가져오기" data-toc-modified-id="Doja-Cat-상위-트랙-5개-가져오기-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Doja Cat 상위 트랙 5개 가져오기</a></span></li><li><span><a href="#Audio-features" data-toc-modified-id="Audio-features-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Audio features</a></span></li><li><span><a href="#트랙-데이터-가져오기" data-toc-modified-id="트랙-데이터-가져오기-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>트랙 데이터 가져오기</a></span></li></ul></li><li><span><a href="#데이터-합치기" data-toc-modified-id="데이터-합치기-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>데이터 합치기</a></span></li></ul></div>

# %% [markdown]
# ### Spotify module 설치

# %%
#!pip install spotipy
# 이때 주의할 점은 module명이 spotify가 아닌 spotipy이다!
# Out:
# ...
#   Obtaining dependency information for spotipy from https://files.pythonhosted.org/packages/b8/e8/4c099f9431ec9a86f576b344702cd4446d1ff7df09b172dc1951f25d58b1/spotipy-2.23.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/65/f2/540ad07910732733138beb192991c67c69e7f6ebf549ce1a3a77846cbae7/redis-5.0.4-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/252.0 kB ? eta -:--:--
#    ---------------------------------------- 252.0/252.0 kB 7.8 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pprint
# pprint는 데이터를 보기 좋게 출력(pretty print)할 때 사용하는 모듈이다.
# 구조가 복잡한 JSON 데이터를 디버깅 용도로 출력할 때 pprint를 자주 사용

# %% [markdown]
# ### API 접속하기 위한 인증 과정

# %%
cid = '271683aabb0b4f22a6adc2a59515605d'  # Client ID
secret = 'f1dad9dc93ff4de9b94795e37ad3ded8'  # Client secret
redirect_uri = 'http://localhost:8080/callback'
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=cid, client_secret=secret, redirect_uri=redirect_uri))

# %% [markdown]
# ### 가수 정보 가져오기

# %% [markdown]
# #### serarch()

# %%
result = sp.search("dojacat", limit=1, type="artist")
pprint.pprint(result)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=dojacat&type=artist&offset=0&limit=1',
#              'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#                         'followers': {'href': None, 'total': 29856668},
#                         'genres': ['dance pop', 'pop'],
#                         'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#                         'id': '5cj0lLjcoR7YOSnhnX0Po5',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/ab6761610000e5ebe94f88ff74ae4ddcab961f97',
#                                     'width': 640},
#                                    {'height': 320,
#                                     'url': 'https://i.scdn.co/image/ab67616100005174e94f88ff74ae4ddcab961f97',
#                                     'width': 320},
#                                    {'height': 160,
# ...

# %% [markdown]
# #### 가수 정보 확인하기

# %%
pprint.pprint(result['artists']['items'][0])
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#  'followers': {'href': None, 'total': 29856668},
#  'genres': ['dance pop', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#  'id': '5cj0lLjcoR7YOSnhnX0Po5',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/ab6761610000e5ebe94f88ff74ae4ddcab961f97',
#              'width': 640},
#             {'height': 320,
#              'url': 'https://i.scdn.co/image/ab67616100005174e94f88ff74ae4ddcab961f97',
#              'width': 320},
#             {'height': 160,
#              'url': 'https://i.scdn.co/image/ab6761610000f178e94f88ff74ae4ddcab961f97',
#              'width': 160}],
#  'name': 'Doja Cat',
#  'popularity': 84,
#  'type': 'artist',
#  'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}

# %% [markdown]
# #### artist()
# - 아티스트 정보 추출

# %%
uri = 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5' # 형태 : spotify:artist:(아티스트 id)
artist = sp.artist(uri)
pprint.pprint(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#  'followers': {'href': None, 'total': 29856668},
#  'genres': ['dance pop', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#  'id': '5cj0lLjcoR7YOSnhnX0Po5',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/ab6761610000e5ebe94f88ff74ae4ddcab961f97',
#              'width': 640},
#             {'height': 320,
#              'url': 'https://i.scdn.co/image/ab67616100005174e94f88ff74ae4ddcab961f97',
#              'width': 320},
#             {'height': 160,
#              'url': 'https://i.scdn.co/image/ab6761610000f178e94f88ff74ae4ddcab961f97',
#              'width': 160}],
#  'name': 'Doja Cat',
#  'popularity': 84,
#  'type': 'artist',
#  'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}

# %%
# 아티스트 id 출력
result = sp.search("dojacat", limit=1, type="artist")
dojacat_uri = result["artists"]["items"][0]["id"];
dojacat_uri
# Out:
# '5cj0lLjcoR7YOSnhnX0Po5'

# %% [markdown]
# #### artist_album
# - 앨범 정보

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pprint
 
cid = '271683aabb0b4f22a6adc2a59515605d'  # Client ID
secret = 'f1dad9dc93ff4de9b94795e37ad3ded8' 
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# artist_albums 기능
search_result = sp.search("dojacat", limit=1, type="artist")
dojacat_ID = search_result["artists"]["items"][0]["id"]
album_result = sp.artist_albums('5cj0lLjcoR7YOSnhnX0Po5', limit=2)
items = album_result["items"]
pprint.pprint(items)
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#                'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#                'id': '5cj0lLjcoR7YOSnhnX0Po5',
#                'name': 'Doja Cat',
#                'type': 'artist',
#                'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#   'available_markets': ['AR',
#                         'AU',
#                         'AT',
#                         'BE',
#                         'BO',
#                         'BR',
#                         'BG',
#                         'CA',
#                         'CL',
#                         'CO',
#                         'CR',
#                         'CY',
#                         'CZ',
#                         'DK',
#                         'DO',
#                         'DE',
#                         'EC',
# ...

# %% [markdown]
# #### album_tracks (album_id, limit)
# - 앨범에 수록된 곡들 정보

# %%
result = sp.album_tracks('6DmPNcfpkXBVRJsEIJY9tl')
pprint.pprint(result)
# Out:
# {'href': 'https://api.spotify.com/v1/albums/6DmPNcfpkXBVRJsEIJY9tl/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#                          'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#                          'id': '5cj0lLjcoR7YOSnhnX0Po5',
#                          'name': 'Doja Cat',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#             'disc_number': 1,
#             'duration_ms': 230480,
#             'explicit': True,
#             'external_urls': {'spotify': 'https://open.spotify.com/track/7DlZH8EiVDgQXNoj3dnyZC'},
#             'href': 'https://api.spotify.com/v1/tracks/7DlZH8EiVDgQXNoj3dnyZC',
#             'id': '7DlZH8EiVDgQXNoj3dnyZC',
#             'is_local': False,
#             'is_playable': False,
#             'name': 'Paint The Town Red',
# ...

# %% [markdown]
# #### Doja Cat 상위 트랙 5개 가져오기

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy

cid = '271683aabb0b4f22a6adc2a59515605d'  # Client ID
secret = 'f1dad9dc93ff4de9b94795e37ad3ded8' 

# Doja Cat
lz_uri = 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

results = sp.artist_top_tracks(lz_uri)

# get top 5 tracks
for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + (track['preview_url'] if track['preview_url'] else "Not available"))
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Paint The Town Red
# audio    : https://p.scdn.co/mp3-preview/f544992f165d4bd069f4d903ff946dc625ba0b8e?cid=271683aabb0b4f22a6adc2a59515605d
# cover art: https://i.scdn.co/image/ab67616d0000b273a840032f14ab22da396e43cb
#
# track    : Agora Hills
# audio    : https://p.scdn.co/mp3-preview/28f256dad9add6e7f56ef0b6af5b0e9febdc62bb?cid=271683aabb0b4f22a6adc2a59515605d
# cover art: https://i.scdn.co/image/ab67616d0000b273a840032f14ab22da396e43cb
#
# track    : Woman
# audio    : https://p.scdn.co/mp3-preview/2ae0b61e45d9a5d6454a3e5ab75f8628dd89aa85?cid=271683aabb0b4f22a6adc2a59515605d
# cover art: https://i.scdn.co/image/ab67616d0000b273be841ba4bc24340152e3a79a
#
# track    : Kiss Me More (feat. SZA)
# audio    : https://p.scdn.co/mp3-preview/2903cc27c1a5bd03f247a7f83ace394c36d3c75f?cid=271683aabb0b4f22a6adc2a59515605d
# cover art: https://i.scdn.co/image/ab67616d0000b273be841ba4bc24340152e3a79a
#
# track    : Streets
# ...

# %% [markdown]
# ####  Audio features
# - 특정 가수의 곡들의 오디오 특성을 가져와 음악 특징 파악

# %%
import pandas as pd

# 특정 가수의 곡들의 트랙 ID를 수집합니다.
artist_id = 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'
artist_albums = sp.artist_albums(artist_id=artist_id, limit=50)
track_ids = []
for album in artist_albums['items']:
    album_tracks = sp.album_tracks(album['id'])
    for track in album_tracks['items']:
        track_ids.append(track['id'])

# 트랙 ID를 사용하여 오디오 특성을 수집하고 DataFrame에 저장합니다.
track_features = []
for t_id in track_ids:
    af = sp.audio_features(t_id)
    track_features.append(af)

# 새로운 DataFrame 생성
tf_df = pd.DataFrame(columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# 트랙의 오디오 특성을 DataFrame에 추가합니다.
for item in track_features:
    tf_df = pd.concat([tf_df, pd.DataFrame(item)], ignore_index=True)

tf_df.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.484   0.675  10    -5.053    0       0.0665       0.38200
# 1         0.798   0.612   7    -8.128    1       0.0846       0.04350
# 2         0.944   0.653   1    -7.781    1       0.1820       0.00947
# 3         0.898   0.684   1    -8.347    1       0.2940       0.02740
# 4         0.636   0.447   9    -7.691    1       0.0308       0.49800
#
#   instrumentalness  liveness  valence    tempo            type  \
# 0                0    0.2970    0.375   77.964  audio_features
# 1         0.000435    0.1200    0.387  101.995  audio_features
# 2         0.000124    0.1780    0.428  120.069  audio_features
# 3                0    0.0762    0.903  152.065  audio_features
# 4         0.000004    0.1490    0.411  143.995  audio_features
#
#                        id                                   uri  \
# 0  4a7DIqwIwx0klBiEMOf3Jn  spotify:track:4a7DIqwIwx0klBiEMOf3Jn
# ...

# %% [markdown]
# #### 트랙 데이터 가져오기

# %%
artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []

for i in range(0, 1000, 50):
    track_results = sp.search(q='artist:Doja Cat', type='track', limit=50, offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

# %%
import pandas as pd
track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'track_popularity' : track_popularity, 'artist_id' : artist_id})
print(track_df.shape)
track_df.head()
# Out:
# (867, 5)
#   artist_name                track_name                track_id  \
# 0    Doja Cat               Agora Hills  7dJYggqjKo71KI9sLzqCs8
# 1    Doja Cat        Paint The Town Red  2IGMVunIBsBLtEQyoI1Mu7
# 2    Doja Cat                     Woman  6Uj1ctrBOjOas8xZXGqKk4
# 3    Doja Cat  Kiss Me More (feat. SZA)  3DarAbFujv6eYNliUTyqtz
# 4    Doja Cat                   Streets  60ynsPSSKe6O3sfwRnIBRf
#
#    track_popularity               artist_id
# 0                83  5cj0lLjcoR7YOSnhnX0Po5
# 1                85  5cj0lLjcoR7YOSnhnX0Po5
# 2                85  5cj0lLjcoR7YOSnhnX0Po5
# 3                82  5cj0lLjcoR7YOSnhnX0Po5
# 4                82  5cj0lLjcoR7YOSnhnX0Po5

# %%
artist_genres = []
for a_id in track_df.artist_id:
    artist = sp.artist(a_id)
    artist_genres.append(artist['genres'])

# %%
track_df = track_df.assign(artist_genres=artist_genres)
print(track_df.shape)
track_df.head()
# Out:
# (867, 6)
#   artist_name                track_name                track_id  \
# 0    Doja Cat               Agora Hills  7dJYggqjKo71KI9sLzqCs8
# 1    Doja Cat        Paint The Town Red  2IGMVunIBsBLtEQyoI1Mu7
# 2    Doja Cat                     Woman  6Uj1ctrBOjOas8xZXGqKk4
# 3    Doja Cat  Kiss Me More (feat. SZA)  3DarAbFujv6eYNliUTyqtz
# 4    Doja Cat                   Streets  60ynsPSSKe6O3sfwRnIBRf
#
#    track_popularity               artist_id     artist_genres
# 0                83  5cj0lLjcoR7YOSnhnX0Po5  [dance pop, pop]
# 1                85  5cj0lLjcoR7YOSnhnX0Po5  [dance pop, pop]
# 2                85  5cj0lLjcoR7YOSnhnX0Po5  [dance pop, pop]
# 3                82  5cj0lLjcoR7YOSnhnX0Po5  [dance pop, pop]
# 4                82  5cj0lLjcoR7YOSnhnX0Po5  [dance pop, pop]

# %%
track_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867 entries, 0 to 866
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       867 non-null    object
#  1   track_name        867 non-null    object
#  2   track_id          867 non-null    object
#  3   track_popularity  867 non-null    int64
#  4   artist_id         867 non-null    object
#  5   artist_genres     867 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 40.8+ KB

# %%
x.value_counts()
# Out:
# artist_genres
# [dance pop, pop]    866
# []                    1
# Name: count, dtype: int64

# %% [markdown]
# ### 데이터 합치기

# %%
doja_pd = pd.concat([tf_df, track_df])

# %%
doja_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1040 entries, 0 to 866
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      173 non-null    float64
#  1   energy            173 non-null    float64
#  2   key               173 non-null    object
#  3   loudness          173 non-null    float64
#  4   mode              173 non-null    object
#  5   speechiness       173 non-null    float64
#  6   acousticness      173 non-null    float64
#  7   instrumentalness  173 non-null    object
#  8   liveness          173 non-null    float64
#  9   valence           173 non-null    float64
#  10  tempo             173 non-null    float64
#  11  type              173 non-null    object
#  12  id                173 non-null    object
#  13  uri               173 non-null    object
#  14  track_href        173 non-null    object
#  15  analysis_url      173 non-null    object
# ...

# %%
df.drop([], axis = 1)
# Out:
#      danceability  energy  key  loudness mode  speechiness  acousticness  \
# 0           0.484   0.675   10    -5.053    0       0.0665       0.38200
# 1           0.798   0.612    7    -8.128    1       0.0846       0.04350
# 2           0.944   0.653    1    -7.781    1       0.1820       0.00947
# 3           0.898   0.684    1    -8.347    1       0.2940       0.02740
# 4           0.636   0.447    9    -7.691    1       0.0308       0.49800
# ..            ...     ...  ...       ...  ...          ...           ...
# 862           NaN     NaN  NaN       NaN  NaN          NaN           NaN
# 863           NaN     NaN  NaN       NaN  NaN          NaN           NaN
# 864           NaN     NaN  NaN       NaN  NaN          NaN           NaN
# 865           NaN     NaN  NaN       NaN  NaN          NaN           NaN
# 866           NaN     NaN  NaN       NaN  NaN          NaN           NaN
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
dojaPd = doja_pd.copy

# %%
# dojaPd DataFrame에서 열 삭제
doja_pd.drop(['artist_name', 'track_name', 'track_id', 'track_popularity', 'artist_id', 'artist_genres'], axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 2
#       1 # dojaPd DataFrame에서 열 삭제
# ----> 2 doja_pd.drop(['artist_name', 'track_name', 'track_id', 'track_popularity', 'artist_id', 'artist_genres'], axis=1, inplace = True)
#       3 doja_pd.head
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
# ...

# %%
doja_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1040 entries, 0 to 866
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      173 non-null    float64
#  1   energy            173 non-null    float64
#  2   key               173 non-null    object
#  3   loudness          173 non-null    float64
#  4   mode              173 non-null    object
#  5   speechiness       173 non-null    float64
#  6   acousticness      173 non-null    float64
#  7   instrumentalness  173 non-null    object
#  8   liveness          173 non-null    float64
#  9   valence           173 non-null    float64
#  10  tempo             173 non-null    float64
#  11  type              173 non-null    object
#  12  id                173 non-null    object
#  13  uri               173 non-null    object
#  14  track_href        173 non-null    object
#  15  analysis_url      173 non-null    object
# ...
